# %% [markdown]
# <a href="https://colab.research.google.com/github/punyakr26-dot/Python-basics/blob/main/Python__basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world")
# Out:
# hello world

# %%
print("punyashree ")
# Out:
# punyashree

# %%
name="punyashree"
year="2007"
print("hello",name)
print(year)
# Out:
# hello punyashree
# 2007

# %%
name="punyashree"
year="2007"
print(name+year)
# Out:
# punyashree2007

# %%
a=10
b=20
print("add",a+b)
print("sub",a-b)
print("mul",a*b)
print("div",a/b)
# Out:
# add 30
# sub -10
# mul 200
# div 0.5

# %%
A=input("Enter your name")
B=input("Enter your branch")
print("Hello",A)
print("My branch is",B)
# Out:
# Enter your namePunyashree
# Enter your branchCSD
# Hello Punyashree
# My branch is CSD

# %%
A=int(input("Enter your first number "))
B=int(input("Enter your second number"))
print(A)
print(B)
print (A+B)
# Out:
# Enter your first number 20
# Enter your second number30
# 20
# 30
# 50

# %%
Age=int(input("Enter your Age:"))
if Age>=18:
   print("you can vote👍")
else:
     print("come again next year🤟")
# Out:
# Enter your Age:18
# you can vote👍
