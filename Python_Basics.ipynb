# %% [markdown]
# <a href="https://colab.research.google.com/github/punyakr26-dot/Python-basics/blob/main/Python_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
marks=int(input ("Enter your marks:"))
if marks>=50:
   print("you can pass")
else:
     print ("you can not pass")
# Out:
# Enter your marks:70
# you can pass

# %%
def greet():
    print("Hello World")

# %%
def greet(name):
    print("Hello",name)
greet("CSE")
greet("CSD")
greet("civil")
greet("mechanical")
# Out:
# Hello CSE
# Hello CSD
# Hello civil
# Hello mechanical
