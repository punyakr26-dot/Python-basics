# %% [markdown]
# <a href="https://colab.research.google.com/github/punyakr26-dot/Python-basics/blob/main/Pythonbasics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
Name = input("Enter your name:")
print("Hello",Name)
print("welcome to python")
# Out:
# Enter your name:Punyashree
# Hello Punyashree
# welcome to python

# %%
friends = ["punya","arpi","teju"]
for friend in friends:
    print(friend)
# Out:
# punya
# arpi
# teju

# %%
A = int(input("Enter 1st number: "))
B = int(input("Enter 2nd number:"))
print("sum",A+B)
# Out:
# Enter 1st number: 20
# Enter 2nd number:40
# sum 60

# %%
# !pip install ColabTurtleplus

# %%
from ColabTurtlePlus.Turtle import Turtle,initializeTurtle
C= Turtle()
C.circle(240)
C.done()
# Out:
#       <svg width="800" height="600">
#         <rect width="100%" height="100%" style="fill:white;stroke:;stroke-width:1"/>
#
#
#         <path d="M 400.0 300.0 A 50 50 0 0 0 400.0 200.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 200.0 A 50 50 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 300.0 A 100 100 0 0 0 400.0 100.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 100.0 A 100 100 0 0 0 400.0 300.0" stroke-linecap="round"
#             fill="transparent" fill-opacity="0" style="stroke:black;stroke-width:1"/><path d="M 400.0 300.0 A 1 1 0 0 0 400.0 298.0" stroke-linecap="round"
# ...
